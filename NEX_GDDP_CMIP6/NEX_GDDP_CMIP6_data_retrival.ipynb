# %% [markdown]
# # This notebook download the data of NEX-GDDP-CMIP6
# ##### Author: Omid Emamjomehzadeh (https://www.omidemam.com/)
# ##### Supervisor: Dr. Omar Wani (https://engineering.nyu.edu/faculty/omar-wani)
# ##### Hydrologic Systems Group @NYU (https://www.omarwani.com/)

# %%
#import libraries
import os
import time
import xarray as xr
import pandas as pd
import fsspec
from pystac_client import Client
import planetary_computer
import datetime

# %%
# Ensure output directory exists
output_dir = r"D:\NEX-GDDP-CMIP6"
os.makedirs(output_dir, exist_ok=True)

# STAC Catalog connection with retry
catalog_url = "https://planetarycomputer-test.microsoft.com/stac"
max_retries = 10
delay = 3  # seconds

for attempt in range(1, max_retries + 1):
    try:
        catalog = Client.open(
            catalog_url,
            modifier=planetary_computer.sign_inplace,
        )
        # Search for GFDL-ESM4 historical data
        search = catalog.search(
            collections=["nasa-nex-gddp-cmip6"],
            datetime="1979/2014",
            query={
                "cmip6:model": {"eq": "GFDL-ESM4"},
                "cmip6:scenario": {"eq": "historical"},
            },
        )

        items = search.item_collection()
        print("✅ Successfully connected to the STAC catalog.")
        break
    except Exception as e:
        print(f"⚠️ Attempt {attempt} failed: {e}")
        time.sleep(delay)
        
else:
    raise RuntimeError(f"❌ Failed to connect after {max_retries} attempts.")



# Loop through items and variables
item =items[10]
for var in ['pr', 'tas', 'hurs', 'huss', 'rlds', 'rsds', 'tasmax', 'tasmin', 'sfcWind']:
    try:
        # Open dataset
        ds = xr.open_dataset(fsspec.open(item.assets[var].href).open())

        # Convert longitude if needed
        if ds.lon.max() > 180:
            ds = ds.assign_coords(lon=(((ds.lon + 180) % 360) - 180))
            ds = ds.sortby('lon')

        # NYS bounding box
        lat_min, lat_max = 40, 45.25
        lon_min, lon_max = -79.75, -72

        # Subset
        ds_nys = ds[var].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))

        # Loop through time
        for i in range(len(ds.time)):
            time_val = ds.time.values[i].strftime("%Y-%m-%d")
            output_path = os.path.join(output_dir, f"{var}_{time_val}.nc")

            # Skip if file exists
            if os.path.exists(output_path):
                print(f"⏩ Skipping (already exists): {output_path}")
                continue

            daily_slice = ds_nys.isel(time=i).expand_dims("time")

            # Save compressed NetCDF
            daily_slice.to_netcdf(
                output_path,
                engine="netcdf4",
                encoding={var: {"zlib": True, "complevel": 6, "shuffle": True}}
            )
            print(f"✅ Saved: {output_path}")
    except Exception as e:
        print(f"⚠️ Failed to process {var} in {item.id}: {e}")
# Out:
# ⚠️ Attempt 1 failed: Internal Server Error
# ⚠️ Attempt 2 failed: Internal Server Error
# ✅ Successfully connected to the STAC catalog.
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-01-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-02-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-03-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-04-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-05-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-06-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-07-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-08-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-09-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-10-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-11-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\pr_2004-12-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-01-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-02-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-03-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-04-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-05-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-06-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-07-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-08-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-09-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-10-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-11-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\tas_2004-12-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\hurs_2004-01-11.nc
# ...
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-04-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-05-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-06-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-07-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-08-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-09-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-03.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-04.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-05.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-06.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-07.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-08.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-09.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-10.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-11.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-12.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-13.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-14.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-15.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-16.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-17.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-18.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-19.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-20.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-21.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-22.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-23.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-24.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-25.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-26.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-27.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-28.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-29.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-30.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-10-31.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-11-01.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-11-02.nc
# ⏩ Skipping (already exists): D:\NEX-GDDP-CMIP6\sfcWind_2004-11-03.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-04.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-05.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-06.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-07.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-08.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-09.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-10.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-11.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-12.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-13.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-14.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-15.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-16.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-17.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-18.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-19.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-20.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-21.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-22.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-23.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-24.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-25.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-26.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-27.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-28.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-29.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-11-30.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-01.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-02.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-03.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-04.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-05.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-06.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-07.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-08.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-09.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-10.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-11.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-12.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-13.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-14.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-15.nc
# ✅ Saved: D:\NEX-GDDP-CMIP6\sfcWind_2004-12-16.nc

# %%
# %load_ext watermark
# Print the Python version and some dependencies
# %watermark -v -m -p xarray,pandas,fsspec,pystac_client,planetary_computer,datetime
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.12.4
# IPython version      : 8.20.0
#
# xarray            : 2024.7.0
# pandas            : 2.2.2
# fsspec            : 2025.3.0
# pystac_client     : 0.8.3
# planetary_computer: 1.0.0
# datetime          : unknown
#
# Compiler    : MSC v.1940 64 bit (AMD64)
# OS          : Windows
# Release     : 11
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 183 Stepping 1, GenuineIntel
# CPU cores   : 24
# Architecture: 64bit
